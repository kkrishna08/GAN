# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Define a basic transform
transform = transforms.Compose([
transforms.ToTensor(),
transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
batch_size=32, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 43518213.20it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# Hyperparameters
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
class Generator(nn.Module):
  def __init__(self, latent_dim):
    super(Generator, self).__init__()
    self.model = nn.Sequential(
    nn.Linear(latent_dim, 128 * 8 * 8),
    nn.ReLU(),
    nn.Unflatten(1, (128, 8, 8)),
    nn.Upsample(scale_factor=2),
    nn.Conv2d(128, 128, kernel_size=3, padding=1),
    nn.BatchNorm2d(128, momentum=0.78),
    nn.ReLU(),
    nn.Upsample(scale_factor=2),
    nn.Conv2d(128, 64, kernel_size=3, padding=1),
    nn.BatchNorm2d(64, momentum=0.78),
    nn.ReLU(),
    nn.Conv2d(64, 3, kernel_size=3, padding=1),
    nn.Tanh()
  )
  def forward(self, z):
    img = self.model(z)
    return img

# %%
class Discriminator(nn.Module):
  def __init__(self):
    super(Discriminator, self).__init__()
    self.model = nn.Sequential(
    nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
    nn.LeakyReLU(0.2),
    nn.Dropout(0.25),
    nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
    nn.ZeroPad2d((0, 1, 0, 1)),
    nn.BatchNorm2d(64, momentum=0.82),
    nn.LeakyReLU(0.25),
    nn.Dropout(0.25),
    nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),


    nn.BatchNorm2d(128, momentum=0.82),
    nn.LeakyReLU(0.2),
    nn.Dropout(0.25),
    nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
    nn.BatchNorm2d(256, momentum=0.8),
    nn.LeakyReLU(0.25),
    nn.Dropout(0.25),
    nn.Flatten(),
    nn.Linear(256 * 5 * 5, 1),
    nn.Sigmoid()
    )
  def forward(self, img):
    validity = self.model(img)
    return validity

# %%
# Define the generator and discriminator
# Initialize generator and discriminator
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)
# Loss function
adversarial_loss = nn.BCELoss()
# Optimizers
optimizer_G = optim.Adam(generator.parameters()\
, lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
, lr=lr, betas=(beta1, beta2))

# %%
for epoch in range(num_epochs):
  for i, batch in enumerate(dataloader):
  # Convert list to tensor
    real_images = batch[0].to(device)
    # Adversarial ground truths
    valid = torch.ones(real_images.size(0), 1, device=device)
    fake = torch.zeros(real_images.size(0), 1, device=device)
    # Configure input
    real_images = real_images.to(device)
    # ---------------------
    # Train Discriminator
    # ---------------------
    optimizer_D.zero_grad()
    # Sample noise as generator input
    z = torch.randn(real_images.size(0), latent_dim, device=device)
    # Generate a batch of images
    fake_images = generator(z)
    # Measure discriminator's ability
    # to classify real and fake images
    real_loss = adversarial_loss(discriminator\
    (real_images), valid)
    fake_loss = adversarial_loss(discriminator\
    (fake_images.detach()), fake)
    d_loss = (real_loss + fake_loss) / 2
    # Backward pass and optimize
    d_loss.backward()
    optimizer_D.step()
    # -----------------
    # Train Generator
    # -----------------
    optimizer_G.zero_grad()
    # Generate a batch of images
    gen_images = generator(z)
    # Adversarial loss
    g_loss = adversarial_loss(discriminator(gen_images), valid)
    # Backward pass and optimize
    g_loss.backward()
    optimizer_G.step()
    # ---------------------
    # Progress Monitoring
    # ---------------------
    if (i + 1) % 100 == 0:
      print(
      f"Epoch [{epoch+1}/{num_epochs}]Batch {i+1}/{len(dataloader)} "
      f"Discriminator Loss: {d_loss.item():.4f} "
      f"Generator Loss: {g_loss.item():.4f}"
      )
# Out:
# Epoch [1/10]Batch 100/1563 Discriminator Loss: 0.5143 Generator Loss: 1.2980
# Epoch [1/10]Batch 200/1563 Discriminator Loss: 0.8614 Generator Loss: 0.6312
# Epoch [1/10]Batch 300/1563 Discriminator Loss: 0.5618 Generator Loss: 1.1114
# Epoch [1/10]Batch 400/1563 Discriminator Loss: 0.4226 Generator Loss: 1.5108
# Epoch [1/10]Batch 500/1563 Discriminator Loss: 0.5520 Generator Loss: 1.1594
# Epoch [1/10]Batch 600/1563 Discriminator Loss: 0.5919 Generator Loss: 1.1733
# Epoch [1/10]Batch 700/1563 Discriminator Loss: 0.7333 Generator Loss: 0.8417
# Epoch [1/10]Batch 800/1563 Discriminator Loss: 0.6249 Generator Loss: 0.8447
# Epoch [1/10]Batch 900/1563 Discriminator Loss: 0.7068 Generator Loss: 0.7190
# Epoch [1/10]Batch 1000/1563 Discriminator Loss: 0.7408 Generator Loss: 1.1673
# Epoch [1/10]Batch 1100/1563 Discriminator Loss: 0.6505 Generator Loss: 0.8851
# Epoch [1/10]Batch 1200/1563 Discriminator Loss: 0.7009 Generator Loss: 0.7440
# Epoch [1/10]Batch 1300/1563 Discriminator Loss: 0.7421 Generator Loss: 0.8052
# Epoch [1/10]Batch 1400/1563 Discriminator Loss: 0.6262 Generator Loss: 1.3609
# Epoch [1/10]Batch 1500/1563 Discriminator Loss: 0.8177 Generator Loss: 0.7289
# Epoch [2/10]Batch 100/1563 Discriminator Loss: 0.4684 Generator Loss: 1.0922
# Epoch [2/10]Batch 200/1563 Discriminator Loss: 0.8616 Generator Loss: 0.8999
# Epoch [2/10]Batch 300/1563 Discriminator Loss: 0.6300 Generator Loss: 0.9697
# Epoch [2/10]Batch 400/1563 Discriminator Loss: 0.7492 Generator Loss: 0.7608
# Epoch [2/10]Batch 500/1563 Discriminator Loss: 0.4301 Generator Loss: 1.5259
# Epoch [2/10]Batch 600/1563 Discriminator Loss: 0.5509 Generator Loss: 1.4536
# Epoch [2/10]Batch 700/1563 Discriminator Loss: 0.7325 Generator Loss: 0.8709
# Epoch [2/10]Batch 800/1563 Discriminator Loss: 0.7024 Generator Loss: 0.8770
# Epoch [2/10]Batch 900/1563 Discriminator Loss: 0.5246 Generator Loss: 1.1717
# Epoch [2/10]Batch 1000/1563 Discriminator Loss: 0.6973 Generator Loss: 1.0023
# Epoch [2/10]Batch 1100/1563 Discriminator Loss: 0.5542 Generator Loss: 0.9053
# Epoch [2/10]Batch 1200/1563 Discriminator Loss: 0.3941 Generator Loss: 1.2701
# Epoch [9/10]Batch 600/1563 Discriminator Loss: 0.7093 Generator Loss: 1.0837
# Epoch [9/10]Batch 700/1563 Discriminator Loss: 0.6148 Generator Loss: 1.0334
# Epoch [9/10]Batch 800/1563 Discriminator Loss: 0.4778 Generator Loss: 1.2293
# Epoch [9/10]Batch 900/1563 Discriminator Loss: 0.4468 Generator Loss: 2.1301
# Epoch [9/10]Batch 1000/1563 Discriminator Loss: 0.4363 Generator Loss: 1.1303
# Epoch [9/10]Batch 1100/1563 Discriminator Loss: 0.5155 Generator Loss: 1.6113
# Epoch [9/10]Batch 1200/1563 Discriminator Loss: 0.2569 Generator Loss: 1.7523
# Epoch [9/10]Batch 1300/1563 Discriminator Loss: 0.5947 Generator Loss: 1.1075
# Epoch [9/10]Batch 1400/1563 Discriminator Loss: 0.6831 Generator Loss: 1.4117
# Epoch [9/10]Batch 1500/1563 Discriminator Loss: 0.6314 Generator Loss: 0.8131
# Epoch [10/10]Batch 100/1563 Discriminator Loss: 0.5215 Generator Loss: 1.4721
# Epoch [10/10]Batch 200/1563 Discriminator Loss: 0.4513 Generator Loss: 1.2208
# Epoch [10/10]Batch 300/1563 Discriminator Loss: 0.6393 Generator Loss: 1.4493
# Epoch [10/10]Batch 400/1563 Discriminator Loss: 0.5433 Generator Loss: 0.8181
# Epoch [10/10]Batch 500/1563 Discriminator Loss: 0.4070 Generator Loss: 1.8432
# Epoch [10/10]Batch 600/1563 Discriminator Loss: 0.5628 Generator Loss: 0.9835
# Epoch [10/10]Batch 700/1563 Discriminator Loss: 0.6796 Generator Loss: 0.8511
# Epoch [10/10]Batch 800/1563 Discriminator Loss: 0.7145 Generator Loss: 1.1226
# Epoch [10/10]Batch 900/1563 Discriminator Loss: 0.4926 Generator Loss: 1.5208
# Epoch [10/10]Batch 1000/1563 Discriminator Loss: 0.6819 Generator Loss: 0.9769
# Epoch [10/10]Batch 1100/1563 Discriminator Loss: 0.5707 Generator Loss: 1.4870
# Epoch [10/10]Batch 1200/1563 Discriminator Loss: 0.4585 Generator Loss: 1.0800
# Epoch [10/10]Batch 1300/1563 Discriminator Loss: 0.6132 Generator Loss: 1.0290
# Epoch [10/10]Batch 1400/1563 Discriminator Loss: 0.4012 Generator Loss: 1.8335
# Epoch [10/10]Batch 1500/1563 Discriminator Loss: 0.4126 Generator Loss: 1.2166

# %%
if (epoch + 1) % 10 == 0:
  with torch.no_grad():
    z = torch.randn(16, latent_dim, device=device)
    generated = generator(z).detach().cpu()
    grid = torchvision.utils.make_grid(generated,\
    nrow=4, normalize=True)
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    plt.axis("off")
    plt.show()

# %%
import os
import torch

# Define a directory to save the model
save_dir = 'saved_models/'
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist

# Define the filename with path
model_file = os.path.join(save_dir, 'generator_model.pth')

# Save the model's state_dict (weights)
torch.save(generator.state_dict(), model_file)
print(f'Model saved to {model_file}')
# Out:
# Model saved to saved_models/generator_model.pth
